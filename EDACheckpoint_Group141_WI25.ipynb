# %% [markdown]
# **If you lost points on the last checkpoint you can get them back by responding to TA/IA feedback**
#
# Update/change the relevant sections where you lost those points, make sure you respond on GitHub Issues to your TA/IA to call their attention to the changes you made here.
#
# Please update your Timeline... no battle plan survives contact with the enemy, so make sure we understand how your plans have changed.

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Derek Chen
# - Andrew Nguyen
# - Nghi Sam
# - Hartej Singh
# - Angela Yuan

# %% [markdown]
# # Research Question

# %% [markdown]
# -  Include a specific, clear data science question.
# -  Make sure what you're measuring (variables) to answer the question is clear
#
# What is your research question? Include the specific question you're setting out to answer. This question should be specific, answerable with data, and clear. A general question with specific subquestions is permitted. (1-2 sentences)
#
# ***
#
# For males and females, ages 18-25, in various college major (Engineering, Medical, Law, etc), which of the factors are most highly correlated with a higher depression score:
#
# - **Sleep Quality Level** (Good = Wake Up Feeling Refreshed, Average = Sleep Enough, Poor = Sleep Very Little)
# - **Diet Quality** (Good = 3+ Meals a Day, Average = 2 Meals a Day, Poor = 0-1 Meal)
# - **Physical Activity Level** (High = Go to the Gym, Moderate = Walking/Slow Jog, Low = Don't Exercise)
# - **Social Support** (High = Feels that there is always someone to talk to when needed, Moderate, Low)
# - **Amount of School Work** (Semester Credit Load)
# - **Financial Pressure** (0 (Living Comfortably) - 5 (Very Stress About Money))
# - **Usage of Counseling Services** (Frequently = Goes Weekly, Occasionally = Goes Monthly, Never = Haven't Been)
# - **Relationship Status** (Single, Married, In A Relationship)
# - **Family History of Depression** (Yes/No)
#
# Additionally, are students of certain majors, gender, university, or age groups more prone to be affected by depression?
#
# ***

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# - Include a general introduction to your topic
# - Include explanation of what work has been done previously
# - Include citations or links to previous work
#
# This section will present the background and context of your topic and question in a few paragraphs. Include a general introduction to your topic and then describe what information you currently know about the topic after doing your initial research. Include references to other projects who have asked similar questions or approached similar problems. Explain what others have learned in their projects.
#
# Find some relevant prior work, and reference those sources, summarizing what each did and what they learned. Even if you think you have a totally novel question, find the most similar prior work that you can and discuss how it relates to your project.
#
# References can be research publications, but they need not be. Blogs, GitHub repositories, company websites, etc., are all viable references if they are relevant to your project. It must be clear which information comes from which references. (2-3 paragraphs, including at least 2 references)
#
#  **Use inline citation through HTML footnotes to specify which references support which statements**
#
# For example: After government genocide in the 20th century, real birds were replaced with surveillance drones designed to look just like birds.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) Use a minimum of 2 or 3 citations, but we prefer more.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) You need enough to fully explain and back up important facts.
#
# Note that if you click a footnote number in the paragraph above it will transport you to the proper entry in the footnotes list below.  And if you click the ^ in the footnote entry, it will return you to the place in the main text where the footnote is made.
#
# To understand the HTML here, `<a name="#..."> </a>` is a tag that allows you produce a named reference for a given location.  Markdown has the construciton `[text with hyperlink](#named reference)` that will produce a clickable link that transports you the named reference.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Lorenz, T. (9 Dec 2021) Birds Aren’t Real, or Are They? Inside a Gen Z Conspiracy Theory. *The New York Times*. https://www.nytimes.com/2021/12/09/technology/birds-arent-real-gen-z-misinformation.html
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Also refs should be important to the background, not some randomly chosen vaguely related stuff. Include a web link if possible in refs as above.
#
# ***
#
# The prevalence of depression among college students has become a significant public health concern, exacerbated by increasing academic pressures, financial strain, and social challenges. College students, particularly those aged 18-25, are in a transitional life stage characterized by greater independence, shifts in social networks, and heightened academic expectations, all of which can contribute to mental health challenges. Studies indicate that depression is widespread within this demographic, with research finding that 53% of American college students reported experiencing depression since starting college, and 9% contemplated suicide (Furr et al., 2021).<a name="ref-2"></a>[<sup>2</sup>](#cite-2) Similarly, it is observed that over a quarter of Swiss university students exhibited depressive symptoms during the COVID-19 pandemic, significantly exceeding both general population and pre-pandemic levels (Volken et al., 2021).<a name="ref-3"></a>[<sup>3</sup>](#cite-3)
#
# Prior research has examined various predictors of depression among college students, often focusing on isolated factors such as socioeconomic status, academic workload, or lifestyle habits. Liu's team and Liu conducted a literature review categorizing non-pathological depression contributors into biological, psychological, academic, and lifestyle factors, emphasizing the role of socioeconomic status, family support, and health behaviors in mitigating depressive symptoms (Liu et al., 2022).<a name="ref-1"></a>[<sup>1</sup>](#cite-1) Additionally, studies have identified certain student subgroups, such as art students and those in Institutes of Technology, as being at higher risk due to field-specific stressors and socioeconomic pressures (McLafferty et al., 2022).<a name="ref-4"></a>[<sup>4</sup>](#cite-4) Researchers have also explored the role of big data and machine learning in depression prediction, utilizing behavioral data from fitness trackers, smartphones, and social networks to assess mental health trends.
#
# However, while previous studies have provided valuable insights into the factors influencing depression, there remains a gap in understanding how multiple lifestyle, social, and academic variables interact to contribute to depression across different academic disciplines. Our research questions seeks to address this gap by investigating which factors—such as sleep quality, diet, physical activity, social support, financial stress, academic workload, counseling service utilization, relationship status, and family history of depression—are most strongly correlated with depression scores among male and female college students from various academic disciplines (e.g., Engineering, Medical, Law, etc.). By examining a more comprehensive set of lifestyle and academic factors within a diverse student population, we aim to provide a more nuanced understanding of the determinants of depression and whether students of certain majors, genders, universities, or age groups are disproportionately affected.
#
# References
#
# 1. <a name="cite-1"></a> [^](#ref-1) Liu, Xin-Qiao et al. “Influencing factors, prediction and prevention of depression in college students: A literature review.” World journal of psychiatry vol. 12,7 860-873. 19 Jul. 2022, doi:10.5498/wjp.v12.i7.860
# 2. <a name="cite-2"></a> [^](#ref-2) Furr, S. R., Westefeld, J. S., McConnell, G. N., & Jenkins, J. M. (2001). Suicide and depression among college students: A decade later. *Professional Psychology: Research and Practice, 32*(1), 97–100. [https://doi.org/10.1037/0735-7028.32.1.97](https://psycnet.apa.org/doi/10.1037/0735-7028.32.1.97)
# 3. <a name="cite-3"></a> [^](#ref-3) Volken T, Zysset A, Amendola S, Klein Swormink A, Huber M, von Wyl A, Dratva J. Depressive Symptoms in Swiss University Students during the COVID-19 Pandemic and Their Correlates. *International Journal of Environmental Research and Public Health*. 2021; 18(4):1458. https://doi.org/10.3390/ijerph18041458
# 4. <a name="cite-4"></a> [^](#ref-4) McLafferty, Margaret et al. “Variations in psychological disorders, suicidality, and help-seeking behaviour among college students from different academic disciplines.” PloS one vol. 17,12 e0279618. 30 Dec. 2022, doi:10.1371/journal.pone.0279618
#
# ***

# %% [markdown]
# # Hypothesis

# %% [markdown]
# - Include your team's hypothesis
# - Ensure that this hypothesis is clear to readers
# - Explain why you think this will be the outcome (what was your thinking?)
#
# What is your main hypothesis/predictions about what the answer to your question is? Briefly explain your thinking. (2-3 sentences)
#
# ***
#
# We believe that the top factor that negatively influences a college student’s depression level is the stress generated from studying. While other factors contribute to depression levels, based on personal experience, it is the stress from studying that influences one the most, and leads to other types of stress developing. As such, while we expect other factors to also contribute to stress, we expect academic stress to contribute the largest.
#
# ***

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name:
#   - Link to the dataset:
#   - Number of observations:
#   - Number of variables:
# - Dataset #2 (if you have more than one!)
#   - Dataset Name:
#   - Link to the dataset:
#   - Number of observations:
#   - Number of variables:
# - etc
#
# Now write 2 - 5 sentences describing each dataset here. Include a short description of the important variables in the dataset; what the metrics and datatypes are, what concepts they may be proxies for. Include information about how you would need to wrangle/clean/preprocess the dataset
#
# If you plan to use multiple datasets, add a few sentences about how you plan to combine these datasets.
#
# ***
#
# - Dataset #1
#   - Dataset Name: Students Mental Health Survey
#   - Link to the dataset: https://www.kaggle.com/datasets/sonia22222/students-mental-health-assessments
#   - Number of observations: 7022
#   - Number of variables: 20
#
# Our dataset features the mental health evaluation of students with valuable insights into numbers of factors that may impact student's mental health. Collected from various anonymous source, we have mainly string ('Course', 'Gender', 'Sleep_Quality', 'Physical_Activity', 'Diet_Quality', 'Social_Support', 'Relationship_Status', 'Counseling_Service_Use', and 'Family_History') and integer ('Age' in years, 'Depression_Score', 'Financial_Stress', and 'Semester_Credit_Load' in semester course units) variables. Besides the 'Depression_Score' variables, which measure a rating of how depressed the student felt, each of the other variables are factors as to what may cause depression, like stressors ('Financial_Stress', 'Semester_Credit_Load'), personal ratings of how well they think they handle daily life activities like eating, sleeping, and exercising ('Sleep_Quality', 'Physical_Activity', 'Diet_Quality'), and other descriptive information about the individual. These variables measured can be taken by its face value as it doesn't seem to be proxies for any other concept.
#
# Originally, our dataset was somewhat clean. The column names are very descriptive and the entries are standardized. We do originally have some missing values, but they were not part of the dataset we want to look at. When we filtered it through age (inclusive integer values 18 through 25) and factors, according to the scope of our project, our new dataset contains no missing values, therefore it was unneccesary to clean much further. The steps we took to clean our dataset, as shown in the code cells below:
# 1) Dropped columns that didn't relate to the target variable we are interested in researching (depression score)
# 2) Drop rows where the age was outside the scope of our project (younger than 18, older than 25)
# 3) Check the datatypes of each column and scan for null values in each feature column in case we need to wrangle those
# 4) Checked the unique entries of each column to see if we needed to standardize any variables or remove any rows (didn't need to do anything here)
# 5) Check the distribution of the dataset in case any transformation is needed.

# %% [markdown]
# ## Students Mental Health Survey Dataset

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the dataframe
df = pd.read_csv('students_mental_health_survey.csv')
df.head()
# Out:
#    Age            Course  Gender  CGPA  Stress_Level  Depression_Score  \
# 0   25            Others    Male  3.56             3                 3
# 1   24       Engineering  Female  2.44             0                 3
# 2   19          Business  Female  3.74             4                 0
# 3   19  Computer Science    Male  3.65             2                 1
# 4   18          Business    Male  3.40             3                 3
#
#    Anxiety_Score Sleep_Quality Physical_Activity Diet_Quality Social_Support  \
# 0              2          Good          Moderate         Good       Moderate
# 1              0       Average               Low      Average            Low
# 2              3          Good               Low      Average       Moderate
# 3              0       Average               Low      Average       Moderate
# 4              4          Good               Low      Average           High
#
# ...

# %%
# Check the size of the dataframe (row by column)
df.shape
# Out:
# (7022, 20)

# %%
# Drop Columns According to the factors we will be analyzing specifically
df = df.drop(columns = ['CGPA', 'Stress_Level', 'Anxiety_Score', 
                        'Substance_Use', 'Chronic_Illness', 
                        'Extracurricular_Involvement', 'Residence_Type'])
df.head()
# Out:
#    Age            Course  Gender  Depression_Score Sleep_Quality  \
# 0   25            Others    Male                 3          Good
# 1   24       Engineering  Female                 3       Average
# 2   19          Business  Female                 0          Good
# 3   19  Computer Science    Male                 1       Average
# 4   18          Business    Male                 3          Good
#
#   Physical_Activity Diet_Quality Social_Support Relationship_Status  \
# 0          Moderate         Good       Moderate             Married
# 1               Low      Average            Low              Single
# 2               Low      Average       Moderate   In a Relationship
# 3               Low      Average       Moderate              Single
# 4               Low      Average           High             Married
#
#   Counseling_Service_Use Family_History  Financial_Stress  \
# 0                  Never             No                 2
# ...

# %%
# Filter rows according to the age group of higher education student 
# we are specifically looking at
df = df[(df['Age'] >= 18) & (df['Age'] <= 25)]
df.head()
# Out:
#    Age            Course  Gender  Depression_Score Sleep_Quality  \
# 0   25            Others    Male                 3          Good
# 1   24       Engineering  Female                 3       Average
# 2   19          Business  Female                 0          Good
# 3   19  Computer Science    Male                 1       Average
# 4   18          Business    Male                 3          Good
#
#   Physical_Activity Diet_Quality Social_Support Relationship_Status  \
# 0          Moderate         Good       Moderate             Married
# 1               Low      Average            Low              Single
# 2               Low      Average       Moderate   In a Relationship
# 3               Low      Average       Moderate              Single
# 4               Low      Average           High             Married
#
#   Counseling_Service_Use Family_History  Financial_Stress  \
# 0                  Never             No                 2
# ...

# %%
# Check if there are any null values to handle
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
# Get shape of new dataframe
df.shape
# Out:
# (5278, 13)

# %%
# Understand the datatype of the dataframe we will work with later on
df.dtypes
# Out:
# Age                        int64
# Course                    object
# Gender                    object
# Depression_Score           int64
# Sleep_Quality             object
# Physical_Activity         object
# Diet_Quality              object
# Social_Support            object
# Relationship_Status       object
# Counseling_Service_Use    object
# Family_History            object
# Financial_Stress           int64
# Semester_Credit_Load       int64
# dtype: object

# %%
# Get the unique value for each column in the dataframe
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values, '\n')
# Out:
# Unique values in column 'Age':
# [25 24 19 18 21 23 22 20]
#
# Unique values in column 'Course':
# ['Others' 'Engineering' 'Business' 'Computer Science' 'Medical' 'Law']
#
# Unique values in column 'Gender':
# ['Male' 'Female']
#
# Unique values in column 'Depression_Score':
# [3 0 1 4 2 5]
#
# Unique values in column 'Sleep_Quality':
# ['Good' 'Average' 'Poor']
#
# Unique values in column 'Physical_Activity':
# ['Moderate' 'Low' 'High']
#
# Unique values in column 'Diet_Quality':
# ['Good' 'Average' 'Poor']
#
# Unique values in column 'Social_Support':
# ['Moderate' 'Low' 'High']
#
# Unique values in column 'Relationship_Status':
# ['Married' 'Single' 'In a Relationship']
#
# Unique values in column 'Counseling_Service_Use':
# ['Never' 'Occasionally' 'Frequently']
#
# Unique values in column 'Family_History':
# ['No' 'Yes']
#
# Unique values in column 'Financial_Stress':
# [2 3 4 0 5 1]
#
# Unique values in column 'Semester_Credit_Load':
# ...

# %%
# Plot distribution of integer values
fig_1, ax_1 = plt.subplots(2, 2)
row = 0
col_n = 0
for col in ['Age', 'Depression_Score', 'Financial_Stress', 'Semester_Credit_Load']:
    # Account for exclusive endpoint in np.arange and inclusive endpoint in bins on the last bin
    bins = np.arange(min(df[col]), max(df[col]) + 2)
    df[col].hist(bins = bins, ax = ax_1[row][col_n])
    ax_1[row][col_n].set_xlabel(col)
    ax_1[row][col_n].set_ylabel('Frequency')
    row += 1
    if row == 2:
        row = 0
        col_n += 1

fig_1.tight_layout()

# %%
# Plot distribution of categorical variables
fig_2, ax_2 = plt.subplots(3, 3)
row = 0
col_n = 0
for col in df.columns:
    if df[col].dtype == object:
        sns.countplot(x = col, data = df, ax = ax_2[row][col_n])
        ax_2[row][col_n].tick_params(axis = 'x', rotation = 90)
        row += 1
        if row == 3:
            row = 0
            col_n += 1
fig_2.set_size_inches(12,12)
fig_2.tight_layout()

# %% [markdown]
# ***

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis
#
# Carry out whatever EDA you need to for your project.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# ***

# %% [markdown]
# ### EDA - Descriptive and Bivariate Analysis
#
# Since all the factors are being compared against the depression scores, we will describe each of the data first by itself to see what information we can obtain, then we will describe the data by each individual group of factors and see what information about the depression score it will bring us.

# %% [markdown]
# #### Individually Described Data:

# %%
# Describe numerical data
df.describe()
# Out:
#                Age  Depression_Score  Financial_Stress  Semester_Credit_Load
# count  5278.000000       5278.000000       5278.000000           5278.000000
# mean     21.200455          2.252558          2.455286             22.017241
# std       2.193325          1.628481          1.709804              4.375831
# min      18.000000          0.000000          0.000000             15.000000
# 25%      19.000000          1.000000          1.000000             18.000000
# 50%      21.000000          2.000000          2.000000             22.000000
# 75%      23.000000          3.000000          4.000000             26.000000
# max      25.000000          5.000000          5.000000             29.000000

# %%
# Describe categorical data
df.describe(include = ['object'])
# Out:
#          Course Gender Sleep_Quality Physical_Activity Diet_Quality  \
# count      5278   5278          5278              5278         5278
# unique        6      2             3                 3            3
# top     Medical   Male          Good          Moderate      Average
# freq       1588   2662          2683              2631         3210
#
#        Social_Support Relationship_Status Counseling_Service_Use  \
# count            5278                5278                   5278
# unique              3                   3                      3
# top          Moderate              Single                  Never
# freq             2602                2678                   3201
#
#        Family_History
# count            5278
# unique              2
# top                No
# freq             3665

# %% [markdown]
# #### Described Depression Score By Individual Group of Factor with Visuals

# %% [markdown]
# Below, we will group the data by factors and determine if there are any unique patterns between depression score amongst each group of factors. Additionally, we will be plotting boxplot with mean (triangle green markers) and countplot to visualize the different groups in each factors because most of our data are categorical and discrete numerical data. For our discrete numberical data, we could plot a scatterplot to find any linear regression pattern, but due to the fact that each numerical values contains all possible 'Depression_Score' value, we won't be able to see any clear patterns with a scatterplot.

# %%
# DO NOT USE, SHOW SCATTERPLOT IS NOT HELPFUL 
# EVEN IN NUMERICAL DATA IN THIS SITUATION
sns.pairplot(df)

# %%
# Map color to hex that are used
color = {'red': '#f69697', 'yellow': '#FFEE8C', 'green': '#90ee90', 'pink': '#ffcbd1', 'light blue': '#ADD8E6'}

# %%
# Create a grouped table of Depression Score by Age
age_depress_group = df.groupby('Age')['Depression_Score'].describe()
display(age_depress_group)

# Create a boxplot of Depression Score by Age
sns.boxplot(x = 'Age', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True, 
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'},
            palette = dict(zip(sorted(df['Age'].unique().astype(str)), 
                               sns.color_palette('YlOrRd', 8))))
plt.title('Depression Score of Student by Age')
plt.xlabel('Age of Students')
plt.ylabel('Depression Score')
# Out:
#      count      mean       std  min  25%  50%  75%  max
# Age
# 18   738.0  2.261518  1.614271  0.0  1.0  2.0  3.0  5.0
# 19   710.0  2.218310  1.644396  0.0  1.0  2.0  3.0  5.0
# 20   723.0  2.290456  1.668099  0.0  1.0  2.0  4.0  5.0
# 21   777.0  2.209781  1.590405  0.0  1.0  2.0  3.0  5.0
# 22   694.0  2.242075  1.678887  0.0  1.0  2.0  4.0  5.0
# 23   642.0  2.364486  1.642223  0.0  1.0  2.0  4.0  5.0
# 24   539.0  2.252319  1.579189  0.0  1.0  2.0  3.0  5.0
# 25   455.0  2.162637  1.588758  0.0  1.0  2.0  3.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\3698356316.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Age',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a scatterplot with regression line
# of mean depression score by age
sns.regplot(data = age_depress_group, 
            x = age_depress_group.index, 
            y = 'mean')
plt.title('Average Depression Score of Student by Age')
plt.xlabel('Age of Students')
plt.ylabel('Mean Depression Score')
# Out:
# Text(0, 0.5, 'Mean Depression Score')

# %% [markdown]
# Observation:
# - There are certain spike in age that cause 'Depression_Score' to be higher from the other ages, like at age 20, 22, and 23
# - However the spike in depression score appears to be random with no clear pattern that an age lower or higher than would increase or decrease depression.
# - Seems like there is not much correlation between 'Age' and 'Depression_Score' but we will explore this further later.

# %%
# Create a grouped table of Depression Score by Financial Stress
financial_depress_group = df.groupby('Financial_Stress')['Depression_Score'].describe()
display(financial_depress_group)

# Create a boxplot of Depression Score by Financial Stress
sns.boxplot(x = 'Financial_Stress', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True,
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'},
            palette = dict(zip(sorted(df['Financial_Stress'].unique().astype(str)), 
                               sns.color_palette('YlOrRd', 6))))
plt.title('Depression Score of Student by Financial Stress Score')
plt.xlabel('Financial Stress Score')
plt.ylabel('Depression Score')
# Out:
#                   count      mean       std  min  25%  50%  75%  max
# Financial_Stress
# 0                 933.0  2.302251  1.614967  0.0  1.0  2.0  4.0  5.0
# 1                 871.0  2.276693  1.596086  0.0  1.0  2.0  3.0  5.0
# 2                 888.0  2.279279  1.672356  0.0  1.0  2.0  4.0  5.0
# 3                 867.0  2.196078  1.639814  0.0  1.0  2.0  3.0  5.0
# 4                 884.0  2.219457  1.643624  0.0  1.0  2.0  3.0  5.0
# 5                 835.0  2.237126  1.603746  0.0  1.0  2.0  4.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\1440304421.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Financial_Stress',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a scatterplot with regression line 
# of mean depression score by financial stress score
sns.regplot(data = financial_depress_group, 
            x = financial_depress_group.index, 
            y = 'mean')
plt.title('Average Depression Score of Student by Financial Stress')
plt.xlabel('Financial Stress Score')
plt.ylabel('Mean Depression Score')
# Out:
# Text(0, 0.5, 'Mean Depression Score')

# %% [markdown]
# Observation:
# - Due to the fact that 'Depression_Score' distribution seems to be approximately the same throughout all 'Financial_Stress' score, it seems that there is not much correlation between 'Financial_Stress' and 'Depression_Score' but we will explore this further later.
# - Although the average depression score seems to have a decreasing trend as financial_stress increases, if we look at the y-axis values, the values appear to be very minimal.

# %%
# Create a grouped table of Depression Score by Semester Credit
credit_depress_group = df.groupby('Semester_Credit_Load')['Depression_Score'].describe()
display(credit_depress_group)

# Create a boxplot of Depression Score by Semester Credit Load
sns.boxplot(x = 'Semester_Credit_Load', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True, 
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'},
            palette = dict(zip(sorted(df['Semester_Credit_Load'].unique().astype(str)), 
                               sns.color_palette('YlOrRd', 15))))
plt.title('Depression Score of Student by Semester Units')
plt.xlabel('Semester Course Load by Units')
plt.ylabel('Depression Score')
# Out:
#                       count      mean       std  min  25%  50%   75%  max
# Semester_Credit_Load
# 15                    358.0  2.290503  1.636239  0.0  1.0  2.0  4.00  5.0
# 16                    352.0  2.178977  1.641454  0.0  1.0  2.0  3.00  5.0
# 17                    387.0  2.098191  1.630560  0.0  1.0  2.0  3.00  5.0
# 18                    350.0  2.191429  1.636068  0.0  1.0  2.0  3.00  5.0
# 19                    342.0  2.157895  1.652754  0.0  1.0  2.0  3.00  5.0
# 20                    344.0  2.218023  1.657783  0.0  1.0  2.0  4.00  5.0
# 21                    322.0  2.208075  1.543814  0.0  1.0  2.0  3.00  5.0
# 22                    348.0  2.244253  1.587268  0.0  1.0  2.0  3.00  5.0
# 23                    329.0  2.294833  1.562129  0.0  1.0  2.0  4.00  5.0
# 24                    344.0  2.281977  1.655143  0.0  1.0  2.0  3.25  5.0
# 25                    342.0  2.257310  1.661498  0.0  1.0  2.0  4.00  5.0
# ...

# %%
# Create a scatterplot with regression line of mean depression score 
# by semester credit load
sns.regplot(data = credit_depress_group, 
            x = credit_depress_group.index, 
            y = 'mean')
plt.title('Average Depression Score of Student by Semester Units')
plt.xlabel('Semester Course Load by Units')
plt.ylabel('Mean Depression Score')
# Out:
# Text(0, 0.5, 'Mean Depression Score')

# %% [markdown]
# Observation:
# - It seems that the distribution of 'Depression_Score' across 'Semester_Credit_Load' has no specific significant patterns, but we do notice a slight increasing pattern in mean 'Depression_Score' as 'Semester_Credit_Load' increases. We will test this later in our prediction model if this increasing pattern will be an important feature that is correlated to 'Depression_Score'.

# %%
course_palette = dict(zip(df['Course'].unique(), 
                          sns.color_palette('pastel', 6)))

# Create a grouped table of Depression Score by Courses
display(df.groupby('Course')['Depression_Score'].describe())

# Create a boxplot of Depression Score by Courses
(sns.boxplot(x = 'Course', 
             y = 'Depression_Score', 
             data = df, 
             showmeans = True, 
             palette = course_palette, 
             meanprops = {'marker': 'o', 
                          'markerfacecolor': 'black', 
                          'markeredgecolor': 'black'})
    .tick_params(axis = 'x', 
                 rotation = 90))
plt.title('Depression Score of Student by Course')
plt.xlabel('Course')
plt.ylabel('Depression Score')
# Out:
#                    count      mean       std  min  25%  50%  75%  max
# Course
# Business           542.0  2.101476  1.592159  0.0  1.0  2.0  3.0  5.0
# Computer Science   786.0  3.278626  1.500735  0.0  2.0  4.0  5.0  5.0
# Engineering        807.0  2.115242  1.578501  0.0  1.0  2.0  3.0  5.0
# Law               1029.0  2.104956  1.555918  0.0  1.0  2.0  3.0  5.0
# Medical           1588.0  2.028338  1.593490  0.0  1.0  2.0  3.0  5.0
# Others             526.0  2.051331  1.603338  0.0  1.0  2.0  3.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\3125421682.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   (sns.boxplot(x = 'Course',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a histogram of Depression Score by Courses
sns.histplot(data = df, 
             x = 'Depression_Score', 
             hue = 'Course', 
             palette = course_palette, 
             kde = True, 
             multiple = 'dodge')
plt.title('Distribution of Depression Score of Student by Course')
plt.xlabel('Depression Score')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %% [markdown]
# Observation:
# - It appears that across any 'Course', the distribution of 'Depression_Score' are approximately the same besides for 'Computer Science'. Students seem to be more depressed amongst those who are taking 'Computer Science' courses compared to those taking any other courses.
# - For now, we assume 'Course' have some correlation with 'Depression_Score'

# %%
gender_palette = {'Male': color['light blue'], 'Female': color['pink']}

# Create a grouped table of Depression Score by Gender
display(df.groupby('Gender')['Depression_Score'].describe())

# Create a boxplot of Depression Score by Gender
sns.boxplot(x = 'Gender', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True, 
            palette = gender_palette,
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'})
plt.title('Depression Score of Student by Gender')
plt.xlabel('Gender')
plt.ylabel('Depression Score')
# Out:
#          count      mean       std  min  25%  50%  75%  max
# Gender
# Female  2616.0  2.265291  1.649137  0.0  1.0  2.0  4.0  5.0
# Male    2662.0  2.240045  1.608135  0.0  1.0  2.0  3.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\418062523.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Gender',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a histogram of Depression Score by Gender
sns.histplot(data = df, 
              x = 'Depression_Score', 
              hue = 'Gender', 
              palette = gender_palette,
              kde = True, 
              multiple = 'dodge')
plt.title('Distribution of Depression Score of Student by Gender')
plt.xlabel('Depression Score')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %% [markdown]
# Observation:
# - From the boxplot, it may appear that gender might have a slight correlation to 'Depression_Score' as 'Female' appears to be slightly more depressed, but our KDE lines shows otherwise.
# - For now, we will conclude that 'Gender' does not play much of a role into 'Depression_Score' until further analysis

# %%
poor_good_palette = {'Poor': color['red'], 
                     'Average': color['yellow'], 
                     'Good': color['green']}

# Create a grouped table of Depression Score by Sleep Quality
display(df.groupby('Sleep_Quality')['Depression_Score'].describe())

# Create a boxplot of Depression Score by Sleep Quality
sns.boxplot(x = 'Sleep_Quality', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True,
            order = poor_good_palette.keys(), 
            palette = poor_good_palette,
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'})
plt.title('Depression Score of Student by Sleep Quality')
plt.xlabel('Sleep Quality')
plt.ylabel('Depression Score')
# Out:
#                 count      mean       std  min  25%  50%  75%  max
# Sleep_Quality
# Average        2073.0  2.255186  1.635750  0.0  1.0  2.0  3.0  5.0
# Good           2683.0  2.250839  1.612797  0.0  1.0  2.0  3.0  5.0
# Poor            522.0  2.250958  1.682086  0.0  1.0  2.0  4.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\2762979397.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Sleep_Quality',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a histogram of Depression Score by Sleep Quality
sns.histplot(data = df, 
             x = 'Depression_Score', 
             hue = 'Sleep_Quality', 
             palette = poor_good_palette, 
             hue_order = poor_good_palette.keys(), 
             kde = True, 
             multiple = 'dodge')
plt.title('Distribution of Depression Score of Student by Sleep Quality')
plt.xlabel('Depression Score')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %% [markdown]
# Observation:
# - From the boxplot, we observed that the average depression score across sleep quality is approximately the same throughout each type of sleep quality. However, the distribution of the depression_score, we noticed that the boxplot for 'Good' and 'Average' are more positively skewed, suggesting that having a good or normal amount of rest is correlated with lower depression score.
# - Furthermore from the KDE, we noticed the same exact pattern that while the depression score count stays roughly equal across the 6 depression scores for 'Poor', they taper off at higher depression score for 'Good' and 'Average'.
# - However, whether or not this slight skewness is significant or not, we will find out with further analysis.

# %%
low_high_palette = {'Low': color['red'], 
                    'Moderate': color['yellow'], 
                    'High': color['green']}

# Create a grouped table of Depression Score by Physical Activity
display(df.groupby('Physical_Activity')['Depression_Score'].describe())

# Create a boxplot of Depression Score by Physical Activity
sns.boxplot(x = 'Physical_Activity', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True,
            order = low_high_palette.keys(), 
            palette = low_high_palette,
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'})
plt.title('Depression Score of Student by Physical Activity')
plt.xlabel('Physical Activity')
plt.ylabel('Depression Score')
# Out:
#                     count      mean       std  min  25%  50%  75%  max
# Physical_Activity
# High               1065.0  2.301408  1.649860  0.0  1.0  2.0  4.0  5.0
# Low                1582.0  2.218078  1.605998  0.0  1.0  2.0  3.0  5.0
# Moderate           2631.0  2.253516  1.633293  0.0  1.0  2.0  3.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\2571419786.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Physical_Activity',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a histogram of Depression Score by Physical Activity
sns.histplot(data = df, 
             x = 'Depression_Score', 
             hue = 'Physical_Activity', 
             palette = low_high_palette, 
             hue_order = low_high_palette.keys(), 
             kde = True, 
             multiple = 'dodge')
plt.title('Distribution of Depression Score of Student by Physical Activity')
plt.xlabel('Depression Score')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %% [markdown]
# Observation:
# - Here we see that the average depression score across physical activity are approximately the same from both the mean in the boxplot and the pattern of the KDE plot. However, 'High' physical activity seem to have a more stable distibution, than 'Low' and 'Moderate' activities, who seems to have a positively skewed data, suggesting a lower depression score from those two categories of physical activities.

# %%
# Create a grouped table of Depression Score by Diet Quality
display(df.groupby('Diet_Quality')['Depression_Score'].describe())

# Create a boxplot of Depression Score by Diet Quality
sns.boxplot(x = 'Diet_Quality', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True,
            order = poor_good_palette.keys(), 
            palette = poor_good_palette,
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'})
plt.title('Depression Score of Student by Diet Quality')
plt.xlabel('Diet Quality')
plt.ylabel('Depression Score')
# Out:
#                count      mean       std  min  25%  50%  75%  max
# Diet_Quality
# Average       3210.0  2.213396  1.619531  0.0  1.0  2.0  3.0  5.0
# Good          1028.0  2.369650  1.644540  0.0  1.0  2.0  4.0  5.0
# Poor          1040.0  2.257692  1.636017  0.0  1.0  2.0  4.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\1353711676.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Diet_Quality',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a histogram of Depression Score by Diet Quality
sns.histplot(data = df, 
             x = 'Depression_Score', 
             hue = 'Diet_Quality', 
             palette = poor_good_palette, 
             hue_order = poor_good_palette.keys(), 
             kde = True, 
             multiple = 'dodge')
plt.title('Distribution of Depression Score of Student by Diet Quality')
plt.xlabel('Depression Score')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %% [markdown]
# Observation:
# - Here we see no clear patterns as to whether or not a 'Good' or 'Poor' diet increase 'Depression_Score', suggesting 'Diet_Quality' have a low correlation, if any, to 'Depression_Score'
# - 'Average' seems to be not uniformly distributed, but positively skewed. This may suggest some pattern, but this can also be due to random chances, which we will analyze further later.
# - However, as of this point, one possible explanation for this positively skewed 'Average' distribution, could be that people either don't eat when they get depressed or they eat too much to relieve some stress.

# %%
# Create a grouped table of Depression Score by Social Support
display(df.groupby('Social_Support')['Depression_Score'].describe())

# Create a boxplot of Depression Score by Social Support
sns.boxplot(x = 'Social_Support', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True,
            order = low_high_palette.keys(), 
            palette = low_high_palette,
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'})
plt.title('Depression Score of Student by Social Support')
plt.xlabel('Social Support')
plt.ylabel('Depression Score')
# Out:
#                  count      mean       std  min  25%  50%  75%  max
# Social_Support
# High            1665.0  2.236637  1.641698  0.0  1.0  2.0  4.0  5.0
# Low             1011.0  2.315529  1.635118  0.0  1.0  2.0  4.0  5.0
# Moderate        2602.0  2.238278  1.617411  0.0  1.0  2.0  3.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\2520851816.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Social_Support',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a histogram of Depression Score by Social Support
sns.histplot(data = df, 
             x = 'Depression_Score', 
             hue = 'Social_Support', 
             palette = low_high_palette, 
             hue_order = low_high_palette.keys(),
             kde = True, 
             multiple = 'dodge',)
plt.title('Distribution of Depression Score of Student by Social Support')
plt.xlabel('Depression Score')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %% [markdown]
# Observation:
# - Similar to 'Diet_Quality', here we also see no clear increasing or decreasing patterns in 'Depression_Score', suggesting 'Social_Support' have a low correlation, if any, to 'Depression_Score'
# - Compared to 'High' and 'Low', which are uniformly distributed, 'Average' seems to be positively skewed. This may suggest some pattern, but this can also be due to random chances, which we will analyze further later.
# - However, as of this point, one possible explanation for this positively skewed 'Moderate' distribution, could be that depressed people either have low amounts of support to help them through depression, thus causing them to be more depressed in general, or they are often depressed, therefore, they seek out a lot of social support.

# %%
single_married_palette = dict(zip(df['Relationship_Status'].unique(), 
                                  sns.color_palette('pastel', 3)))

# Create a grouped table of Depression Score by Relationship Status
display(df.groupby('Relationship_Status')['Depression_Score'].describe())

# Create a boxplot of Depression Score by Relationship Status
sns.boxplot(x = 'Relationship_Status', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True,
            order = ['Single', 'In a Relationship', 'Married'],
            palette = single_married_palette,
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'})
plt.title('Depression Score of Student by Relationship Status')
plt.xlabel('Relationship Status')
plt.ylabel('Depression Score')
# Out:
#                       count      mean       std  min  25%  50%  75%  max
# Relationship_Status
# In a Relationship    1562.0  2.246479  1.628955  0.0  1.0  2.0  3.0  5.0
# Married              1038.0  2.316956  1.606616  0.0  1.0  2.0  4.0  5.0
# Single               2678.0  2.231143  1.636564  0.0  1.0  2.0  3.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\2804738841.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Relationship_Status',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a distribution of Depression Score by Relationship Status
sns.histplot(data = df, 
             x = 'Depression_Score', 
             hue = 'Relationship_Status', 
             hue_order = ['Single', 'In a Relationship', 'Married'],
             palette = single_married_palette,
             kde = True, 
             multiple = 'dodge')
plt.title('Distribution of Depression Score of Student by Relationship Status')
plt.xlabel('Depression Score')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %% [markdown]
# Observation:
# - Here, we noticed that as of 'Relationship_Status', being 'Single' or 'In a Relationship' have a positively skewed 'Depression_Score', suggesting overall people may be less depressed if they are not 'Married'. However, our KDE plot relative distribution suggest this may not be significant, but we will explore this further later.
# - As of currently, we believe that this non-uniformed distribution between 'Single' and 'In a Relationship' may be due to the fact that they have less to worry about, allowing more time to care for themselves, lowering depression. Being 'Married' means that the person have a full-time job taking care of their kids, if any, and their significant others, but that's not true across all 'Married' relationship, thus explaining why it is uniformed.

# %%
never_freq_palette = {'Never': color['red'], 
                      'Occasionally': color['yellow'], 
                      'Frequently': color['green']}

# Create a grouped table of Depression Score by Counseling Service Use
display(df.groupby('Counseling_Service_Use')['Depression_Score'].describe())

# Create a boxplot of Depression Score by Counseling Service Usage
sns.boxplot(x = 'Counseling_Service_Use', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True,
            order = never_freq_palette.keys(), 
            palette = never_freq_palette,
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'})
plt.title('Depression Score of Student by Counseling Service Usage')
plt.xlabel('Counseling Service Usage')
plt.ylabel('Depression Score')
# Out:
#                          count      mean       std  min  25%  50%  75%  max
# Counseling_Service_Use
# Frequently               528.0  2.284091  1.619020  0.0  1.0  2.0  4.0  5.0
# Never                   3201.0  2.250234  1.611343  0.0  1.0  2.0  3.0  5.0
# Occasionally            1549.0  2.246611  1.667402  0.0  1.0  2.0  4.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\1649143998.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Counseling_Service_Use',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a histogram of Depression Score by Counseling Service Usage
sns.histplot(data = df, 
             x = 'Depression_Score', 
             hue = 'Counseling_Service_Use', 
             palette = never_freq_palette, 
             hue_order = never_freq_palette.keys(), 
             kde = True, 
             multiple = 'dodge')
plt.title('Distribution of Depression Score of Student by Counseling Usage')
plt.xlabel('Depression Score')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %% [markdown]
# Observation:
# - Here we noticed that people who 'Never' had any 'Counseling_Service_Use' are less depressed than those who has some experience with counseling, showing a clear dip in density as the 'Depression_Score' gets higher.
# -  It can be due to the fact that people who don't have depression don't find the need to use counseling service

# %%
no_yes_palette = never_freq_palette = {'No': color['red'], 
                                       'Yes': color['green']}

# Create a grouped table of Depression Score by Family History
display(df.groupby('Family_History')['Depression_Score'].describe())

# Create a boxplot of Depression Score by Family History of Depression
sns.boxplot(x = 'Family_History', 
            y = 'Depression_Score', 
            data = df, 
            showmeans = True, 
            palette = no_yes_palette,
            meanprops = {'marker': 'o', 
                         'markerfacecolor': 'black', 
                         'markeredgecolor': 'black'})
plt.title('Depression Score of Student by Family History')
plt.xlabel('Family History')
plt.ylabel('Depression Score')
# Out:
#                  count      mean       std  min  25%  50%  75%  max
# Family_History
# No              3665.0  2.242838  1.627905  0.0  1.0  2.0  3.0  5.0
# Yes             1613.0  2.274644  1.630078  0.0  1.0  2.0  4.0  5.0
# C:\Users\nghis\AppData\Local\Temp\ipykernel_35080\1840587384.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Family_History',
# Text(0, 0.5, 'Depression Score')

# %%
# Create a histogram of Depression Score by Family History of Depression
sns.histplot(data = df, 
             x = 'Depression_Score', 
             hue = 'Family_History', 
             palette = no_yes_palette,
             kde = True, 
             multiple = 'dodge')
plt.title('Distribution of Depression Score of Student by Family History')
plt.xlabel('Depression Score')
plt.ylabel('Frequency of Students')
# Out:
# Text(0, 0.5, 'Frequency of Students')

# %% [markdown]
# Observation:
# - Here, we observed that people with 'No' 'Family_History' of depression seems to have a more positively skewed graph, suggesting they may have lower depression score than those who does have a family history of depression.
# - This may suggest that there are some genetic factors to depression being involved, where those whose parents do not have depression are less likely in general to get depression or if they do, would have a lower depression score.
#
# Overall Observation:
# - None of the factors, besides 'Course', seems to have a clear definitive boundaries between each individual Depression_Score, suggesting a much more complex interconnected relationship being involved.
#
# ### Outliers and Patterns
#
# The outliers in the data might be caused due to major life transitions that tend to occur at this age, such as attending college, adapting to independent living, or managing academic and social pressure. The years that have been examined are full of responsibility and uncertainty and therefore school, work, and life balance is especially challenging. In examining the correlation between depression scores and age, one can see the peaks at 20, 22, and 23 where students will be more depressed. That being said, there is not a trend that can be stated that being older or younger does not directly equate to higher or lower depression scores. This indicates that other variables, such as external stressors, may have more of an influence than age itself. Another trend in the data is that while most of the students from different courses all have the same degree of depression, Computer Science students are significantly higher. This could mean that the course one is studying influences his or her mind state, perhaps due to a combination of factors like workload, level of difficulty, or competitiveness of certain majors.
#
# Given the likely causes of depression and the trends resulting in the same, academic aspects (course selection and credit load each semester) seem to hold greater relevance than personal aspects such as financial issues, sleeping patterns, or lifestyle. One trend that remains constant is that students with greater numbers of units have greater depression scores, and this indicates that carrying a heavy academic load is a stressor and a precursor to mental issues. Similarly, Computer Science majors have the highest depression rates across all majors which could be due to the rigorous curriculum or late hours of programming and studying. On the other hand, financial difficulty, diet, and exercise do not have strong trends in the data, so perhaps they do not have as direct an influence on depression (at least not for the students in this sample). This means that college stress has a greater impact on student well-being compared to some individual characteristics, and this necessitates the delivery of better mental health services in college, especially to students in poorly performing majors.

# %% [markdown]
# ***

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# - Thoughtful discussion of ethical concerns included
# - Ethical concerns consider the whole data science process (question asked, data collected, data being used, the bias in data, analysis, post-analysis, etc.)
# - How your group handled bias/ethical concerns clearly described
#
# Acknowledge and address any ethics & privacy related issues of your question(s), proposed dataset(s), and/or analyses. Use the information provided in lecture to guide your group discussion and thinking. If you need further guidance, check out [Deon's Ethics Checklist](http://deon.drivendata.org/#data-science-ethics-checklist). In particular:
#
# - Are there any biases/privacy/terms of use issues with the data you propsed?
# - Are there potential biases in your dataset(s), in terms of who it composes, and how it was collected, that may be problematic in terms of it allowing for equitable analysis? (For example, does your data exclude particular populations, or is it likely to reflect particular human biases in a way that could be a problem?)
# - How will you set out to detect these specific biases before, during, and after/when communicating your analysis?
# - Are there any other issues related to your topic area, data, and/or analyses that are potentially problematic in terms of data privacy and equitable impact?
# - How will you handle issues you identified?
#
# ***
#
# Privacy and ethics are important in researching students’ mental states especially since we are examining students' private lives, such as their sleep, study hours, and diet, to answer the question. Additionally, since our role in this project is researchers, not therapists, having unprofessional discussions with the participants about their mental states may bring about negative reactions, like PTSD. In these cases, we hoped to find existing datasets done by professionals. Otherwise, if we were to survey from scratch, we would like to ask specific questions that are neither too personal nor too triggering, with considerations arising from concerns. In terms of datasets, it is possible for there to be human biases, especially since we are asking participants to self-diagnose or give a score to their happiness or depression. To resolve this in an existing dataset, we can be extra careful in our analysis and look at borderline results more carefully. However, if we were to collect data from scratch, we could give a comprehensive answer choice for each ranking to prevent human biases, giving examples of what each score means so that participants don't randomly guess their score.
#
# Furthermore, bias may appear in our data if it is taken from only one school or students of a specific background, not representating of all higher education students. Using a diverse dataset will give us the most effective and accurate data. To avoid these issues, our group will do our best to find a dataset that is not directly collected from one group and has similar commonalities such as school, race, religion, or gender. If we are unable to find a dataset with a variety of students, we will generalize whatever we find in our analysis to that specific population from which our dataset was obtained.
#
# Since privacy, bias, and ethics are very important in our research, we will do our best to detect and resolve them throughout the project. We understand that it is important to communicate to the participants how their information will be used, protected, and stored; therefore first and foremost, we will get informed consent from our participants during the data collection period and allow them to opt-out whenever they want. During data collection, we will also try to watch out for bias by following our guide to avoiding human bias in the dataset above. While doing our analysis and using the participants's data, we will take utmost care of the data security and privacy of our participants. To ensure that the participants can trust us to keep their data and not opt out, we will remove identifying information about the subjects that are not needed, like their names, and store all the data safely. Furthermore, in our analysis, we will avoid creating multiple models to ensure not one algorithm is prone to bias.
#
# Finally, in our conclusion/communication stage, we will consider bias and ethics by showing proof from our analysis. If our datasets are not representative of our original population, we will only generalize our analysis to the scope of the people who were represented in the dataset. It is also important to consider the difference between correlation and causation, which will allow us to avoid the cognitive bias mistake of trying to turn our correlation into causation.
#
# ***

# %% [markdown]
# # Team Expectations

# %% [markdown]
# Read over the [COGS108 Team Policies](https://github.com/COGS108/Projects/blob/master/COGS108_TeamPolicies.md) individually. Then, include your group’s expectations of one another for successful completion of your COGS108 project below. Discuss and agree on what all of your expectations are. Discuss how your team will communicate throughout the quarter and consider how you will communicate respectfully should conflicts arise. By including each member’s name above and by adding their name to the submission, you are indicating that you have read the COGS108 Team Policies, accept your team’s expectations below, and have every intention to fulfill them. These expectations are for your team’s use and benefit — they won’t be graded for their details.
#
# ***
#
# Our team will aim to communicate twice a week whenever possible, with meetings scheduled on Mondays around 4 PM. These meetings will take place both virtually and in person, with additional communication occurring via text as needed. In all interactions, team members are expected to maintain a tone that is both polite and honest. When making decisions, the team will operate on a majority-based approach to ensure fairness and efficiency.
#
# ***

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# Specify your team's specific project timeline. An example timeline has been provided. Changes the dates, times, names, and details to fit your group's plan.
#
# If you think you will need any special resources or training outside what we have covered in COGS 108 to solve your problem, then your proposal should state these clearly. For example, if you have selected a problem that involves implementing multiple neural networks, please state this so we can make sure you know what you’re doing and so we can point you to resources you will need to implement your project. Note that you are not required to use outside methods.
#
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/20  |  4 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 1/27  |  4 AM |  Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 2/9  | 8 AM  | Edit, finalize, and submit proposal; Search for datasets  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 2/23  | 12 PM  | Import & Wrangle Data (Nghi/Hertej); EDA (Nghi/Hertej) | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 2/28  | 4 PM  | Finalize wrangling/EDA (Nghi/Hertej); Begin Analysis (Angela/Derek/Andrew) | Discuss/edit Analysis; Complete project check-in |
# | 3/10  | 4 PM  | Complete analysis; Draft results/conclusion/discussion (Everyone)| Discuss/edit full project |
# | 3/17  | 4 PM  | NA | Turn in Final Project & Group Project Surveys |
